# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open("../DATA/00-puppy.jpg")

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()[:,:,2]

# %%
plt.imshow(pic_red,cmap="gray")

# %%
pic_g_zeros = pic_arr.copy()
pic_g_zeros[:,:,0]=0
pic_g_zeros[:,:,2]=0

type(pic_g_zeros)
# Out:
# numpy.ndarray

# %%
plt.imshow(pic_g_zeros)
