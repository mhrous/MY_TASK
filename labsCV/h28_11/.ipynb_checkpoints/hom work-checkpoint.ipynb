# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams["figure.figsize"] = (18,12)

# %%
img = cv2.imread('1.jpg',0)

# %%
plt.imshow(img,cmap='gray')

# %%
hist = cv2.calcHist([img],channels=[0],mask=None,histSize=[256],ranges=[0,256])
plt.plot(hist)

# %%
img_equalized = cv2.equalizeHist(img)
plt.imshow(img_equalized,cmap='gray')

# %%
img1 = cv2.imread('4.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread('5.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
img1_shape=img1.shape
img2_shape=img2.shape
print(img1_shape,img2_shape)
# Out:
# (853, 480, 3) (853, 480, 3)

# %%
alpha = 0.5

img1 =cv2.resize(img2,(1200,1200))
beta = (1.0 - alpha)
img1_img2 = cv2.addWeighted(src1=img1,alpha=0.7,src2=img2,beta=0.9,gamma=-50)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-42-a129823c09d5> in <module>
#       3 img1 =cv2.resize(img2,(1200,1200))
#       4 beta = (1.0 - alpha)
# ----> 5 dst = cv2.addWeighted(img1, alpha, img2, beta, 0.0)
#
# error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\core\src\arithm.cpp:659: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'
