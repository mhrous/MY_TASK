# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
plt.rcParams["figure.figsize"] = (18,12)

# %%
img = cv2.imread("s.jpg")
img_gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
edge = cv2.Canny(img_gray,20,150)
lines =cv2.HoughLines(edge,1,np.pi/180,50)
if lines is not None:
    
    for i in range(len(lines)):
        rho = lines[i][0][0]
        theta = lines[i][0][1]
        a = math.sin(theta)
        b = math.cos(theta)
        xo = a * rho
        yo = b * rho
        x1 = int(xo + 1000*(-b))
        y1 = int(yo + 1000*(a))
        x2 = int(xo - 1000*(-b))
        y2 = int(yo - 1000*(a))
        cv2.line(img,(x1,y1),(x2,y2),(0,0,255),3)
        plt.imshow(img)

# %%
img = cv2.imread("opencvlogo.png")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
circlces = cv2.HoughCircles(gray,cv2.HOUGH_GRADIENT,1,23,param1=100,param2=40,minRadius=0,maxRadius=0)
circlces = np.uint16(np.round(circlces))

# %% [raw]
# for i in circlces[0,:]

# %%
for i in circlces[0,:]:
    cv2.circle(img,(i[0],i[1]),i[2],(0,225,0,2),4)
    cv2.circle(img,(i[0],i[1]),2,(255,225,0,2),4)

# %%
plt.imshow(img)

# %%
img = cv2.imread("chess.png")
img =cv2.resize(img,(600,600))

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img = np.float32(img_size)
dst = cv2.cornerHarris(gray,9,5,0.05)
dst = cv2.dilate(dst,None)
plt.imshow(dst)
img_size[dst>0.01 * dst.max()]=(0,0,255)
plt.imshow(img_size)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-6db88da0e459> in <module>
#       4 dst = cv2.dilate(dst,None)
#       5 plt.imshow(dst)
# ----> 6 img_size[dst>0.01 * dst.max()]=(0,0,255)
#       7 plt.imshow(img_size)
#
# ValueError: NumPy boolean array indexing assignment cannot assign 3 input values to the 10313 output values where the mask is true

# %%
img = cv2.imread("m1.jpg")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
sift = cv2.xfeatures2d.SIFT_create(10)
kp =sift.detect(gray,None)
img = cv2.drawKeypoints(gray,kp, img,None,4)
plt.imshow(img)
